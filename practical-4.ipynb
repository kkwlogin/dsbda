# %%
import pandas as pd

# %%
data = pd.read_csv('C:/Users/91992/OneDrive/Documents/sem-6/DSBD/practical/facebook.csv', sep=';')

# %%
data.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
data.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %% [markdown]
# ## Data Subsets

# %%
subset_data = data[['Page total likes', 'Type', 'Category']]
subset_data.head()
# Out:
#    Page total likes    Type  Category
# 0            139441   Photo         2
# 1            139441  Status         2
# 2            139441   Photo         3
# 3            139441   Photo         2
# 4            139441   Photo         2

# %%
photo_data = data[data['Type']=='Status']
photo_data.head()
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1             139441  Status         2          12             3         10
# 5             139441  Status         2          12             1          9
# 8             139441  Status         2          12             7          3
# 10            139441  Status         2          12             5         10
# 15            138414  Status         2          12             3         10
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 1    0.0                      10460                            19057
# 5    0.0                      10472                            20849
# 8    0.0                      11844                            22538
# 10   0.0                      21744                            42334
# 15   0.0                      10060                            19680
#
#     Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %% [markdown]
# ## Sorting data

# %%
sort_data = data.sort_values(by='Post Weekday', ascending=False)
sort_data.head()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 250            129600  Photo         1           7             7          6
# 428            100732  Photo         1           3             7         15
# 430            100732   Link         1           3             7         14
# 431            100732  Photo         1           3             7         12
# 380            111620  Photo         1           4             7         14
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 250   1.0                       5848                             9068
# 428   0.0                       5132                             9067
# 430   0.0                       2933                             5144
# 431   0.0                       4094                             7469
# 380   0.0                     128064                           251269
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %% [markdown]
# ## Transpose data

# %%
transpose_data = data.T
transpose_data.head()
# Out:
#                      0       1       2       3       4       5       6    \
# Page total likes  139441  139441  139441  139441  139441  139441  139441
# Type               Photo  Status   Photo   Photo   Photo  Status   Photo
# Category               2       2       3       2       2       2       3
# Post Month            12      12      12      12      12      12      12
# Post Weekday           4       3       3       2       2       1       1
#
#                      7       8       9    ...    490    491    492    493  \
# Page total likes  139441  139441  139441  ...  85979  85979  85979  85093
# Type               Photo  Status   Photo  ...  Photo  Photo   Link  Photo
# Category               3       2       3  ...      3      3      1      3
# Post Month            12      12      12  ...      1      1      1      1
# Post Weekday           7       7       6  ...      6      6      5      1
#
#                     494    495    496    497    498    499
# ...

# %% [markdown]
# ## shape of data

# %%
rows, col = data.shape
print("original data shape:", rows, col)
# Out:
# original data shape: 500 19

# %% [markdown]
# ## reshape the data

# %%
import numpy as np
reshaped_data = np.array(data).reshape(-1, 4)

# %%
reshaped_data
# Out:
# array([[139441, 'Photo', 2, 12],
#        [4, 3, 0.0, 2752],
#        [5091, 178, 109, 159],
#        ...,
#        [4188, 7292, 564, 524],
#        [743, 3861, 2200, 316],
#        [0, 91.0, 28.0, 119]], dtype=object)

# %%
reshaped_data.shape
# Out:
# (2375, 4)

# %% [markdown]
# ## merge the data

# %%
data1 = pd.DataFrame({
'id':[1, 2, 3],
'name':['riya', 'diya' , 'jiya']
})

# %%
data2 = pd.DataFrame({
'id':[1, 2, 3],
'salary':[100, 200, 300]
})

# %%
merged = pd.merge(data1, data2, on='id')

# %%
merged
# Out:
#    id  name  salary
# 0   1  riya     100
# 1   2  diya     200
# 2   3  jiya     300
